# %%
import pandas as pd
df=pd.read_csv('day27.csv')
print(df)
# Out:
#        Name  age         city  marks
# 0     shana   23       London     90
# 1     fidha   21      Newyork    100
# 2      zuha   18       Europe     80
# 3  Rinshida   23        Dubai     30
# 4     Hasna   24  Switzerland     40

# %%
print(df["Name"])
print(df[["Name","age"]])
# Out:
# 0       shana
# 1       fidha
# 2        zuha
# 3    Rinshida
# 4       Hasna
# Name: Name, dtype: object
#        Name  age
# 0     shana   23
# 1     fidha   21
# 2      zuha   18
# 3  Rinshida   23
# 4     Hasna   24

# %%
print(df.loc[0,"Name"])
# Out:
# shana

# %%
print(df.loc[0])
print(df.iloc[1])
print(df[0:2])
# Out:
# Name      shana
# age          23
# city     London
# marks        90
# Name: 0, dtype: object
# Name       fidha
# age           21
# city     Newyork
# marks        100
# Name: 1, dtype: object
#     Name  age     city  marks
# 0  shana   23   London     90
# 1  fidha   21  Newyork    100

# %%
print(df[df["marks"]>50])
# Out:
#     Name  age     city  marks
# 0  shana   23   London     90
# 1  fidha   21  Newyork    100
# 2   zuha   18   Europe     80

# %%
print(df[df["city"]=="Newyork"])
# Out:
#     Name  age     city  marks
# 1  fidha   21  Newyork    100

# %%
filter=(df['marks']>50)&(df['city']=="Newyork")
print(df[filter])
# Out:
#     Name  age     city  marks
# 1  fidha   21  Newyork    100
