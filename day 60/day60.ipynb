# %%
while True:
    print("College Enquiry menu Chatbot")
    print("1.course fee")
    print("2.Duration")
    print("3.Eligibility")
    print("4.Contact")
    print("5.Hostel information")
    print("6.placement information")
    print("7.Exit")
    choice=input("Enter your choice:")
    if choice=="1":
        print("Course fee is 170000")
    elif choice=="2":
        print("Duration 2 years")
    elif choice=="3":
        print("Eligibility is plus two")
    elif choice=="4":
        print("Contact 2934247927")
    elif choice=="5":
        print("Hostel information goes here")
    elif choice=="6":
        print("Placement information goes here")
    elif choice=="7":
        print("Exit")
        break
    else:
        print("Invalid choice")
# Out:
# College Enquiry menu Chatbot
# 1.course fee
# 2.Duration
# 3.Eligibility
# 4.Contact
# 5.Hostel information
# 6.placement information
# 7.Exit
# Contact 2934247927
# College Enquiry menu Chatbot
# 1.course fee
# 2.Duration
# 3.Eligibility
# 4.Contact
# 5.Hostel information
# 6.placement information
# 7.Exit
# Hostel information goes here
# College Enquiry menu Chatbot
# 1.course fee
# 2.Duration
# 3.Eligibility
# 4.Contact
# 5.Hostel information
# 6.placement information
# 7.Exit
# Exit

# %%
responses={
    "1": "Course fee is 170000",
    "2": "Duration 2 years",    
    "3": "Eligibility is plus two",
    "4": "Contact 2934247927",


}
while True:
    print("College Enquiry menu Chatbot")
    print("1.course fee")
    print("2.Duration")
    print("3.Eligibility")
    print("4.Contact")
    print("5.Hostel information")
    print("6.placement information")
    print("7.Exit")
    choice=input("Enter your choice:")
    if choice == "7":
        print("Exit")
        break
    print(responses.get(choice, "Invalid choice"))
# Out:
# College Enquiry menu Chatbot
# 1.course fee
# 2.Duration
# 3.Eligibility
# 4.Contact
# 5.Hostel information
# 6.placement information
# 7.Exit
# Course fee is 170000
# College Enquiry menu Chatbot
# 1.course fee
# 2.Duration
# 3.Eligibility
# 4.Contact
# 5.Hostel information
# 6.placement information
# 7.Exit
# Duration 2 years
# College Enquiry menu Chatbot
# 1.course fee
# 2.Duration
# 3.Eligibility
# 4.Contact
# 5.Hostel information
# 6.placement information
# 7.Exit
# Eligibility is plus two
# College Enquiry menu Chatbot
# 1.course fee
# 2.Duration
# 3.Eligibility
# 4.Contact
# 5.Hostel information
# 6.placement information
# 7.Exit
# Contact 2934247927
# College Enquiry menu Chatbot
# 1.course fee
# 2.Duration
# 3.Eligibility
# 4.Contact
# 5.Hostel information
# 6.placement information
# 7.Exit
# Invalid choice
# College Enquiry menu Chatbot
# 1.course fee
# 2.Duration
# 3.Eligibility
# 4.Contact
# 5.Hostel information
# 6.placement information
# 7.Exit
# Invalid choice
# ...

# %%
while True:

    print("\n========== College Enquiry Chatbot ==========")
    print("1. Course Fee")
    print("2. Course Duration")
    print("3. Eligibility")
    print("4. College Location")
    print("5. Contact Number")
    print("6. Exit")

    choice = input("Enter your choice: ")

    if choice == "1":
        print("Course Fee: ₹15,000")

    elif choice == "2":
        print("Course Duration: 3 Months")

    elif choice == "3":
        print("Eligibility: Plus Two Pass")

    elif choice == "4":
        print("College Location: Kochi")

    elif choice == "5":
        print("Contact Number: 9876543210")

    elif choice == "6":
        print("Thank you for visiting!")
        break

    else:
        print("Invalid Choice!")

    continue_choice = input("\nWould you like to continue? (yes/no): ").lower()

    if continue_choice == "no":
        print("Thank you! Have a nice day.")
        break
# Out:
# ========== College Enquiry Chatbot ==========
# 1. Course Fee
# 2. Course Duration
# 3. Eligibility
# 4. College Location
# 5. Contact Number
# 6. Exit
# Course Fee: ₹15,000
#
# ========== College Enquiry Chatbot ==========
# 1. Course Fee
# 2. Course Duration
# 3. Eligibility
# 4. College Location
# 5. Contact Number
# 6. Exit
# Thank you for visiting!
