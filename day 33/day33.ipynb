# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
data={
    "Study hours":[1,2,3,4,5,6,7,8],
    "Marks":[10,20,30,40,50,60,70,80],
    "Sleep hours":[8,7,6,5,4,3,2,1]
}
df=pd.DataFrame(data)
print(df)
print(df.corr())
# Out:
#    Study hours  Marks  Sleep hours
# 0            1     10            8
# 1            2     20            7
# 2            3     30            6
# 3            4     40            5
# 4            5     50            4
# 5            6     60            3
# 6            7     70            2
# 7            8     80            1
#              Study hours  Marks  Sleep hours
# Study hours          1.0    1.0         -1.0
# Marks                1.0    1.0         -1.0
# Sleep hours         -1.0   -1.0          1.0

# %%
sns.heatmap(df.corr(),annot=True)
plt.show()

# %%
sns.pairplot(df)
plt.show()

# %%
sns.scatterplot(x="Study hours", y="Marks", data=df)
plt.show()

# %%
data={
    "salary":[10000,20000,30000,40000,50000,60000,70000,80000],
    "experience":[1,2,3,4,5,6,7,8],
}
df=pd.DataFrame(data)
sns.scatterplot(x="experience", y="salary", data=df)
plt.show()

# %%
data={
    "Temperature":[30,32,34,36,38,40,42,44],
    "Sales":[100,200,300,400,500,600,700,800],
}
df=pd.DataFrame(data)
sns.scatterplot(x="Temperature",y="Sales",data=df)
plt.show()

# %%
data={
    "student":[1,2,3,4,5,6,7,8],
    "marks":[10,20,30,40,50,60,70,80]
}
df=pd.DataFrame(data)
print(df.corr())
# Out:
#          student  marks
# student      1.0    1.0
# marks        1.0    1.0

# %%
data={
    "Employee":[1,2,3,4,5,6,7,8],
    "Salary":[10000,20000,30000,40000,50000,60000,70000,80000]
}
df=pd.DataFrame(data)
print(df.corr())
# Out:
#           Employee  Salary
# Employee       1.0     1.0
# Salary         1.0     1.0

# %%
data={
    "Hospital":[1,2,3,4,5,6,7,8],
    "Patients":[100,200,300,400,500,600,700,800]

}

df=pd.DataFrame(data)
print(df.corr())
# Out:
#           Hospital  Patients
# Hospital       1.0       1.0
# Patients       1.0       1.0
