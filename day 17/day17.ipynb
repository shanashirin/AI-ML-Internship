# %%
import math
print(math.sqrt(16))
print(math.pow(2,3))
print(math.ceil(2.3))
print(math.floor(2.7))
# Out:
# 4.0
# 8.0
# 3
# 2

# %%
print(math.pi)
# Out:
# 3.141592653589793

# %%
import random
print(random.random())
print(random.randint(1,10))
print(random.choice(['apple', 'banana', 'cherry']))
# Out:
# 0.058076034031759094
# 2
# banana

# %%
import datetime
now=datetime.datetime.now()
print(now)
# Out:
# 2026-04-28 13:59:34.771056

# %%
print(now.strftime("%Y-%m-%d %H:%M:%S"))
# Out:
# 2026-04-28 13:57:50

# %%
year = now.year
month = now.month

print("Year:", year)
print("Month:", month)
# Out:
# Year: 2026
# Month: 4

# %%
import matplotlib.pyplot as plt
x=[10,20,30,40,50]
y=[2,4,6,8,10]
plt.plot(x,y)
plt.show()

# %%
plt.bar(x,y)
plt.show()

# %%
student=["shana","haniya","sara","maria"]
marks=[90,85,70,50]
plt.figure()
plt.bar(student,marks)
plt.xlabel("Students")
plt.ylabel("Marks")
plt.title("Student Marks")
plt.show()
