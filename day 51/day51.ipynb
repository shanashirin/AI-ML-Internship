# %%
10 NLP Applications Used in Daily Life
ChatGPT
Google Assistant
Siri
Alexa
Gmail Spam Detection
Google Translate
Predictive Text in WhatsApp
Customer Support Chatbots
Amazon Review Analysis
YouTube Comment Analysis

# %%
5 Apps That Use NLP
ChatGPT
WhatsApp
Gmail
Google Translate
Amazon Shopping

# %%
20 Positive Reviews
Excellent product.
Very useful and reliable.
I love this app.
Amazing quality.
Highly recommended.
Great customer service.
Easy to use.
Fantastic experience.
Worth every penny.
Outstanding performance.
Fast delivery.
Beautiful design.
Works perfectly.
Very satisfied.
Superb quality.
User-friendly interface.
Best purchase ever.
Impressive features.
Extremely helpful.
Five-star experience.

# %%
20 Negative Reviews
Poor quality.
Very disappointing.
Waste of money.
Not recommended.
Terrible experience.
Product stopped working.
Slow performance.
Bad customer support.
Difficult to use.
Overpriced product.
Low quality materials.
Did not meet expectations.
Delivery was delayed.
Frequent crashes.
Not worth buying.
Very frustrating.
Defective product.
Unhelpful features.
Unsatisfactory service.
One-star experience.

# %%
How ChatGPT Uses NLP

ChatGPT uses Natural Language Processing (NLP) to understand and generate human language. When a user asks a question, ChatGPT analyzes the text, understands its meaning and context, and then generates a relevant response. NLP helps ChatGPT recognize words, sentences, grammar, and intent, enabling natural and meaningful conversations with users.

# %%
NLP Workflow Diagram
Text Data
    │
    ▼
Text Cleaning
    │
    ▼
Text Processing
    │
    ▼
Feature Extraction
    │
    ▼
Model Training
    │
    ▼
Prediction
