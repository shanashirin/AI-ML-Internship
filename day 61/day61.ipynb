# %%
text="HELLO,I WANT TO BOOK A TICKET."
text=text.lower()
tokens=text.split()
print(text)
print(tokens)
# Out:
# hello,i want to book a ticket.
# ['hello,i', 'want', 'to', 'book', 'a', 'ticket.']

# %%
text="i love learning artificial intelligence ."
tokens=text.split()
print(tokens)
# Out:
# ['i', 'love', 'learning', 'artificial', 'intelligence', '.']

# %%
text='ArithmeticError is the base class for those built-in exceptions that are raised for various arithmetic errors. It is a subclass of the Exception class. ArithmeticError is not meant to be directly inherited by user-defined classes; it is intended to be used as a base class for other built-in exceptions that represent specific arithmetic errors, such as ZeroDivisionError, OverflowError, and FloatingPointError.'
tokens=text.split()
print(tokens)
# Out:
# ['ArithmeticError', 'is', 'the', 'base', 'class', 'for', 'those', 'built-in', 'exceptions', 'that', 'are', 'raised', 'for', 'various', 'arithmetic', 'errors.', 'It', 'is', 'a', 'subclass', 'of', 'the', 'Exception', 'class.', 'ArithmeticError', 'is', 'not', 'meant', 'to', 'be', 'directly', 'inherited', 'by', 'user-defined', 'classes;', 'it', 'is', 'intended', 'to', 'be', 'used', 'as', 'a', 'base', 'class', 'for', 'other', 'built-in', 'exceptions', 'that', 'represent', 'specific', 'arithmetic', 'errors,', 'such', 'as', 'ZeroDivisionError,', 'OverflowError,', 'and', 'FloatingPointError.']

# %%
# Book a flight to Chennai on Friday.
# flight booking

# %%
# | Feature    | Stemming                                             | Lemmatization                                         |
# | ---------- | ---------------------------------------------------- | ----------------------------------------------------- |
# | Definition | Removes prefixes or suffixes to obtain the root word | Converts a word to its correct dictionary (base) form |
# | Speed      | Faster                                               | Slower                                                |
# | Method     | Rule-based                                           | Dictionary-based                                      |
# | Accuracy   | Less accurate                                        | More accurate                                         |
# | Output     | May produce invalid words                            | Produces meaningful words                             |
# | Example 1  | Playing → Play                                       | Running → Run                                         |
# | Example 2  | Studies → Studi                                      | Better → Good                                         |
# | Example 3  | Running → Run                                        | Children → Child                                      |
