# %%
# Out:
# ...
#   Using cached chromadb-1.5.9-cp39-abi3-win_amd64.whl.metadata (5.1 kB)
# ...
#   Using cached pybase64-1.4.3-cp313-cp313-win_amd64.whl.metadata (9.1 kB)
# ...
#   Using cached uvicorn-0.51.0-py3-none-any.whl.metadata (6.6 kB)
# ...
#   Using cached onnxruntime-1.27.0-cp313-cp313-win_amd64.whl.metadata (5.6 kB)
# ...
#   Using cached pypika-0.51.1-py2.py3-none-any.whl.metadata (51 kB)
# ...
#   Using cached importlib_resources-7.1.0-py3-none-any.whl.metadata (4.0 kB)
# ...
#   Using cached kubernetes-36.0.3-py2.py3-none-any.whl.metadata (1.8 kB)
# ...
#   Using cached mmh3-5.2.1-cp313-cp313-win_amd64.whl.metadata (15 kB)
# ...
#   Using cached orjson-3.11.9-cp313-cp313-win_amd64.whl.metadata (43 kB)
# ...
#   Using cached pyproject_hooks-1.2.0-py3-none-any.whl.metadata (1.3 kB)
# ...
#   Using cached requests_oauthlib-2.0.0-py2.py3-none-any.whl.metadata (11 kB)
# ...
#   Using cached durationpy-0.10-py3-none-any.whl.metadata (340 bytes)
# ...
#   Using cached aiohttp-3.14.1-cp313-cp313-win_amd64.whl.metadata (8.5 kB)
# ...

# %%
import chromadb
client=chromadb.Client()
collection=client.create_collection(
    name="college_data"
)

# %%
collection.add(
    documents=[
        "AI internship fee is 5000",
        "Duration is 3 months",
        "Eligibility is any graduate",
        "Hostel available",
        "100% placement assistance"
    ],
    ids=[
        "1",
        "2",
        "3",
        "4",
        "5"
    
    ]
)
# Out:
# C:\Users\shana\.cache\chroma\onnx_models\all-MiniLM-L6-v2\onnx.tar.gz: 100%|██████████| 79.3M/79.3M [00:27<00:00, 3.06MiB/s]

# %%
results=collection.query(
    query_texts=[
        "How long is the internship?",
    ],
    n_results=2
)
print(results)
# Out:
# {'ids': [['1', '2']], 'embeddings': None, 'documents': [['AI internship fee is 5000', 'Duration is 3 months']], 'uris': None, 'included': ['metadatas', 'documents', 'distances'], 'data': None, 'metadatas': [[None, None]], 'distances': [[0.8467867970466614, 1.0006685256958008]]}

# %%
# import faiss
# Text

# ↓

# Embedding Model

# ↓

# Embeddings

# ↓

# Create FAISS Index

# ↓

# Store Vectors

# ↓

# User Question

# ↓

# Convert Question into Embedding

# ↓

# Similarity Search

# ↓

# Best Matching Vector

# ↓

# Answer

# %%
# | Feature              | ChromaDB                                       | FAISS                                                | Pinecone                                                                        |
# | -------------------- | ---------------------------------------------- | ---------------------------------------------------- | ------------------------------------------------------------------------------- |
# | **Open Source**      | Yes                                            | Yes                                                  | No (Managed cloud service)                                                      |
# | **Cloud Support**    | Limited (Self-hosted)                          | No                                                   | Yes                                                                             |
# | **Ease of Use**      | Easy                                           | Moderate                                             | Easy                                                                            |
# | **Stores Documents** | Yes                                            | No (Stores vectors only)                             | Yes                                                                             |
# | **Stores Metadata**  | Yes                                            | No                                                   | Yes                                                                             |
# | **Best Use Cases**   | RAG applications, AI chatbots, document search | High-speed similarity search, large-scale AI systems | Enterprise AI applications, cloud-based semantic search, recommendation systems |
