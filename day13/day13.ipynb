# %%
print("Hello")
# Out:
# Hello

# %%
try:
    x=int("abc")
except ValueError:
    print("invalid data type")
# Out:
# invalid data type

# %%
nums=[1,2,3]
print(nums[2])
# Out:
# 3

# %%
nums=[1,2,3,4]
print(sum(nums))
# Out:
# 10

# %%
nums=[4,3,2,5,1]
sorted_nums=sorted(nums)
print(sorted_nums)
# Out:
# [1, 2, 3, 4, 5]

# %%
names=["Alice","Bob","Charlie"]
for name in names:
    print(f"Hello, {name}!")
# Out:
# Hello, Alice!
# Hello, Bob!
# Hello, Charlie!

# %%
def add(x,y):
    return x+y
print(add(5,3))
print(add(7,2))
# Out:
# 8
# 9

# %%
def square(x):
    return x*x
print(square(4))
# Out:
# 16
