# %%
import sys
print(sys.executable)
# Out:
# d:\Anaconda\python.exe

# %%
# !pip --version
# Out:
# pip 25.3 from D:\Anaconda\Lib\site-packages\pip (python 3.13)

# %%
pip install ultralytics
# Out:
# ...
#   Using cached ultralytics-8.4.65-py3-none-any.whl.metadata (41 kB)
# ...
#   Using cached polars-1.41.2-py3-none-any.whl.metadata (10 kB)
# ...
#   Using cached ultralytics_thop-2.0.20-py3-none-any.whl.metadata (14 kB)
# ...
#   Using cached polars_runtime_32-1.41.2-cp310-abi3-win_amd64.whl.metadata (1.5 kB)
# ...
# Using cached ultralytics-8.4.65-py3-none-any.whl (1.3 MB)
# Using cached polars-1.41.2-py3-none-any.whl (833 kB)
# Using cached polars_runtime_32-1.41.2-cp310-abi3-win_amd64.whl (52.0 MB)
# Using cached ultralytics_thop-2.0.20-py3-none-any.whl (28 kB)
# ...
#
#    ---------------------------------------- 0/4 [polars-runtime-32]
#    ---------------------------------------- 0/4 [polars-runtime-32]
#    ---------------------------------------- 0/4 [polars-runtime-32]
#    ---------------------------------------- 0/4 [polars-runtime-32]
#    ---------------------------------------- 0/4 [polars-runtime-32]
#    ---------------------------------------- 0/4 [polars-runtime-32]
# ...

# %%
from ultralytics import YOLO
model= YOLO('yolov8n.pt')

# %%
result=model("image.jpg", show=True)
# Out:
# image 1/1 d:\AI-ML-Internship\Day 1\AI-ML-Internship\day 45\image.jpg: 416x640 1 person, 1 car, 4 dogs, 233.2ms
# Speed: 27.2ms preprocess, 233.2ms inference, 39.8ms postprocess per image at shape (1, 3, 416, 640)

# %%
result=model([
    "image.jpg",
    "image2.jpg",
    "image3.jpg"
],save=True)
# Out:
# 0: 640x640 1 person, 1 car, 1 truck, 3 dogs, 1 suitcase, 402.5ms
# 1: 640x640 1 cat, 402.5ms
# 2: 640x640 1 person, 1 chair, 1 cell phone, 1 vase, 1 teddy bear, 402.5ms
# Speed: 4.8ms preprocess, 402.5ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to D:\AI-ML-Internship\Day 1\AI-ML-Internship\runs\detect\predict
