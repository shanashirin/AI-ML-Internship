# %%
from langchain_chroma import Chroma
from langchain_huggingface import HuggingFaceEmbeddings

embedding = HuggingFaceEmbeddings(
    model_name="sentence-transformers/all-MiniLM-L6-v2"
)

vectorstore = Chroma(
    persist_directory="./chroma_db",
    embedding_function=embedding
)

retriever = vectorstore.as_retriever(
    search_kwargs={"k":3}
)

print("Retriever Created Successfully")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 from langchain_chroma import Chroma
#       2 from langchain_huggingface import HuggingFaceEmbeddings
#       4 embedding = HuggingFaceEmbeddings(
#       5     model_name="sentence-transformers/all-MiniLM-L6-v2"
#       6 )
#
# ModuleNotFoundError: No module named 'langchain_chroma'

# %%
questions = [
    "What is AI?",
    "What is Machine Learning?",
    "How long is the internship?",
    "Explain RAG.",
    "What is Deep Learning?"
]

for q in questions:
    print("\nQuestion:", q)
    docs = retriever.invoke(q)

    for i, doc in enumerate(docs, 1):
        print(f"\nChunk {i}")
        print(doc.page_content)
# Out:
# Question: What is AI?
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 11
#       9 for q in questions:
#      10     print("\nQuestion:", q)
# ---> 11     docs = retriever.invoke(q)
#      13     for i, doc in enumerate(docs, 1):
#      14         print(f"\nChunk {i}")
#
# NameError: name 'retriever' is not defined

# %%
# | Feature              | Keyword Search | Dense Retrieval |
# | -------------------- | -------------- | --------------- |
# | Exact word matching  | ✅              | ❌               |
# | Understands meaning  | ❌              | ✅               |
# | Handles synonyms     | ❌              | ✅               |
# | Accuracy             | Medium         | High            |
# | Best for AI chatbots | ❌              | ✅               |

# %%
# Two well-known systems that use BM25 or similar keyword-ranking techniques are:

# Elasticsearch
# Apache Solr

# Both are widely used for enterprise search and document retrieval.
# Out:
#   Cell In[10], line 1
#     Two well-known systems that use BM25 or similar keyword-ranking techniques are:
#         ^
# SyntaxError: invalid syntax

# %%
# | Retriever        | Advantages                                    | Disadvantages                            | Use Cases                               |
# | ---------------- | --------------------------------------------- | ---------------------------------------- | --------------------------------------- |
# | Sparse Retrieval | Fast, simple, efficient for exact keywords    | Cannot understand meaning or synonyms    | Basic keyword search                    |
# | Dense Retrieval  | Understands semantic meaning, highly accurate | Requires embeddings and more computation | AI chatbots, RAG systems                |
# | BM25             | Better keyword ranking than simple search     | Still keyword-based                      | Search engines, document search         |
# | Hybrid Search    | Highest accuracy by combining methods         | More resource-intensive                  | Enterprise RAG, advanced search systems |
