# %%
pip install gensim
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import gensim.downloader as api
model=api.load("glove-wiki-gigaword-100")
print(model['king'])
# Out:
# [==================================================] 100.0% 128.1/128.1MB downloaded
# [-0.32307  -0.87616   0.21977   0.25268   0.22976   0.7388   -0.37954
#  -0.35307  -0.84369  -1.1113   -0.30266   0.33178  -0.25113   0.30448
#  -0.077491 -0.89815   0.092496 -1.1407   -0.58324   0.66869  -0.23122
#  -0.95855   0.28262  -0.078848  0.75315   0.26584   0.3422   -0.33949
#   0.95608   0.065641  0.45747   0.39835   0.57965   0.39267  -0.21851
#   0.58795  -0.55999   0.63368  -0.043983 -0.68731  -0.37841   0.38026
#   0.61641  -0.88269  -0.12346  -0.37928  -0.38318   0.23868   0.6685
#  -0.43321  -0.11065   0.081723  1.1569    0.78958  -0.21223  -2.3211
#  -0.67806   0.44561   0.65707   0.1045    0.46217   0.19912   0.25802
#   0.057194  0.53443  -0.43133  -0.34311   0.59789  -0.58417   0.068995
#   0.23944  -0.85181   0.30379  -0.34177  -0.25746  -0.031101 -0.16285
#   0.45169  -0.91627   0.64521   0.73281  -0.22752   0.30226   0.044801
# ...

# %%
print(model.most_similar("king"))
# Out:
# [('prince', 0.7682328820228577), ('queen', 0.7507690787315369), ('son', 0.7020888328552246), ('brother', 0.6985775232315063), ('monarch', 0.6977890729904175), ('throne', 0.6919989585876465), ('kingdom', 0.6811409592628479), ('father', 0.6802029013633728), ('emperor', 0.6712858080863953), ('ii', 0.6676074266433716)]

# %%
print(model.most_similar('computer'))
# Out:
# [('computers', 0.8751984238624573), ('software', 0.8373122215270996), ('technology', 0.7642159461975098), ('pc', 0.7366448640823364), ('hardware', 0.7290390729904175), ('internet', 0.7286775708198547), ('desktop', 0.7234441637992859), ('electronic', 0.7221828699111938), ('systems', 0.7197922468185425), ('computing', 0.7141730785369873)]

# %%
# Research One Real-world Application of FastText
# Application: Spam Email Detection

# FastText is widely used in spam email classification.

# Why is it suitable?
# Handles misspelled words often found in spam emails.
# Understands rare or newly created words.
# Generates embeddings using character n-grams.
# Fast and efficient even on large datasets.
# Improves classification accuracy.

# Example:

# Spam email:

# Congratulationzz!!
# You won a free prize!!!

# Even though "Congratulationzz" is misspelled, FastText can recognize it because it analyzes character patterns.
