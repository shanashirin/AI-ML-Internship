# %%
import pandas as pd
import numpy as np 
data={
    "Name":["Rahul","Ramesh","Rinu",None],
    "Marks":[85,np.nan,78,65],
    "City":["Kochi","Trivandrum",None,"Kollam"]
}

df=pd.DataFrame(data)
print(df)
# Out:
#      Name  Marks        City
# 0   Rahul   85.0       Kochi
# 1  Ramesh    NaN  Trivandrum
# 2    Rinu   78.0        None
# 3    None   65.0      Kollam

# %%
print(df.isnull())
print(df.isnull().sum())
# Out:
#     Name  Marks   City
# 0  False  False  False
# 1  False   True  False
# 2  False  False   True
# 3   True  False  False
# Name     1
# Marks    1
# City     1
# dtype: int64

# %%
print(df.dropna())
print(df.dropna(axis=1))
# Out:
#     Name  Marks   City
# 0  Rahul   85.0  Kochi
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2, 3]

# %%
print(df.fillna("Unknown"))
numeric_cols=df.select_dtypes(include=np.number).columns
df[numeric_cols]=df[numeric_cols].fillna(df[numeric_cols].mean())
df["Marks"].fillna(df["Marks"].mean())
# Out:
#       Name    Marks        City
# 0    Rahul     85.0       Kochi
# 1   Ramesh  Unknown  Trivandrum
# 2     Rinu     78.0     Unknown
# 3  Unknown     65.0      Kollam
# 0    85.0
# 1    76.0
# 2    78.0
# 3    65.0
# Name: Marks, dtype: float64

# %%
df_duplicated=pd.concat([df,df.iloc[[1]]],ignore_index=True)
print(df_duplicated)
print(df.duplicated())
print(df.drop_duplicates())
# Out:
#      Name  Marks        City
# 0   Rahul     85       Kochi
# 1  Ramesh     90  Trivandrum
# 2    Rinu     78        None
# 3    None     65      Kollam
# 4  Ramesh     90  Trivandrum
# 0    False
# 1    False
# 2    False
# 3    False
# dtype: bool
#      Name  Marks        City
# 0   Rahul     85       Kochi
# 1  Ramesh     90  Trivandrum
# 2    Rinu     78        None
# 3    None     65      Kollam

# %%
df.rename(columns={"Marks":"Score"},inplace=True)
print(df)
# Out:
#      Name  Score        City
# 0   Rahul     85       Kochi
# 1  Ramesh     90  Trivandrum
# 2    Rinu     78        None
# 3    None     65      Kollam

# %%
df["Score"]=df["Score"].astype(int)
print(df)
# Out:
#      Name  Score        City
# 0   Rahul     85       Kochi
# 1  Ramesh     90  Trivandrum
# 2    Rinu     78        None
# 3    None     65      Kollam
